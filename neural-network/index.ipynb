# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
pd.set_option('display.max_columns', None)

# %%
breast_cancer = load_breast_cancer()
breast_cancer_df = pd.DataFrame(data=breast_cancer.data, columns=breast_cancer.feature_names)
breast_cancer_df["label"] = breast_cancer.target

# %%
sns.heatmap(breast_cancer_df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
breast_cancer_df.shape
# Out:
# (569, 31)

# %%
breast_cancer_df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  radius error  texture error  perimeter error  \
# 0                 0.07871        1.0950         0.9053            8.589
# 1                 0.05667        0.5435         0.7339            3.398
# 2                 0.05999        0.7456         0.7869            4.585
# 3                 0.09744        0.4956         1.1560            3.445
# 4                 0.05883        0.7572         0.7813            5.438
#
#    area error  smoothness error  compactness error  concavity error  \
# 0      153.40          0.006399            0.04904          0.05373
# 1       74.08          0.005225            0.01308          0.01860
# 2       94.03          0.006150            0.04006          0.03832
# 3       27.23          0.009110            0.07458          0.05661
# 4       94.44          0.011490            0.02461          0.05688
#
#    concave points error  symmetry error  fractal dimension error  \
# 0               0.01587         0.03003                 0.006193
# 1               0.01340         0.01389                 0.003532
# 2               0.02058         0.02250                 0.004571
# 3               0.01867         0.05963                 0.009208
# 4               0.01885         0.01756                 0.005115
#
#    worst radius  worst texture  worst perimeter  worst area  worst smoothness  \
# 0         25.38          17.33           184.60      2019.0            0.1622
# 1         24.99          23.41           158.80      1956.0            0.1238
# 2         23.57          25.53           152.50      1709.0            0.1444
# 3         14.91          26.50            98.87       567.7            0.2098
# 4         22.54          16.67           152.20      1575.0            0.1374
#
#    worst compactness  worst concavity  worst concave points  worst symmetry  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    worst fractal dimension  label
# 0                  0.11890      0
# 1                  0.08902      0
# 2                  0.08758      0
# 3                  0.17300      0
# 4                  0.07678      0

# %%
breast_cancer.target_names
# Out:
# array(['malignant', 'benign'], dtype='<U9')

# %%
from adaline import AdalineGD
from adalineSGB import AdalineSGD
from perceptron import Perceptron
from plot_decision_regions import plot_decision_regions

# %%
# y = breast_cancer_df.iloc[0:100, -1].values
# y = np.where(y == 'malignant', -1, 1)

# X = breast_cancer_df.iloc[0:100, [0, 2]].values

# plt.scatter(X[:50, 0], X[:50, 1], c="red", marker='o', label="malignant")
# plt.scatter(X[50:100, 0], X[50:100, 1], c="blue", marker='o', label="benign")
# plt.xlabel('mean radius')
# plt.ylabel('mean perimeter')
# plt.legend(loc="upper left")
# plt.show()

# %%
X = breast_cancer.data
y = breast_cancer.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, train_size=0.7)

# %%
(train_data, val_data, train_labels, val_labels) = train_test_split(X_train, y_train,
test_size=0.1, random_state=84)

# %%
ppn = Perceptron(eta=0.1, n_iter=10)
ppn.fit(X_train, y_train)
plt.plot(range(1, len(ppn.errors_) + 1), ppn.errors_, marker="o")
plt.xlabel("Epochs")
plt.ylabel("Number of updates")
plt.show()

# %%
# plot_decision_regions(X, y, classifier=ppn)
# plt.xlabel('sepal length [cm]')
# plt.ylabel('petal length [cm]')
# plt.legend(loc="upper left")
# plt.show()

# %%
y_pred = ppn.predict(val_data)
accuracy_score(val_labels, y_pred)
# Out:
# 0.65

# %%
from sklearn.linear_model import Perceptron

clf = Perceptron(tol=1e-3, random_state=0)
clf.fit(X, y)
# Out:
# Perceptron()

# %%
clf.score(X, y)
# Out:
# 0.9261862917398945

# %% [markdown]
# # AdalineGD

# %%
ada_gd = AdalineGD(n_iter=15, eta=0.01)
ada_gd.fit(X, y)

plt.plot(range(1, len(ada_gd.cost_) + 1), ada_gd.cost_, marker="o")
plt.xlabel('Epochs')
plt.ylabel("Sum-squared-error")
plt.tight_layout()
plt.show()

# %%
y_pred = ada_gd.predict(val_data)
accuracy_score(val_labels, y_pred)
# Out:
# 0.0

# %% [markdown]
# # Adaline SGD

# %%
ada_sgd = AdalineSGD(n_iter=15, eta=0.01, random_state=1)
ada_sgd.fit(X, y)

plt.plot(range(1, len(ada_sgd.cost_) + 1), ada_sgd.cost_, marker="o")
plt.xlabel('Epochs')
plt.ylabel("Average Cost")
plt.tight_layout()
plt.show()
# Out:
# /home/davisf/Documentos/ml2023-Davi-dos-Santos/neural-network/adalineSGB.py:75: RuntimeWarning: overflow encountered in scalar power
#   cost = 0.5 * error ** 2
# /home/davisf/Documentos/ml2023-Davi-dos-Santos/neural-network/adalineSGB.py:73: RuntimeWarning: invalid value encountered in add
#   self.w_[1:] += self.eta * xi.dot(error)
# /home/davisf/Documentos/ml2023-Davi-dos-Santos/neural-network/adalineSGB.py:74: RuntimeWarning: invalid value encountered in scalar add
#   self.w_[0] += self.eta * error
